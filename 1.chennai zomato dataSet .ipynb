# %% [markdown]
# # chennai zomato dataset

# %% [markdown]
# # important libary's

# %%
import pandas as pd
import numpy as np

# visulation purpase
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # import the dataset

# %%
dataSet = pd.read_csv('Zomato Chennai Listing 2020.csv')

# %%
dataSet.head()
# Out:
#                                           Zomato URL     Name of Restaurant  \
# 0  https://www.zomato.com/chennai/yaa-mohaideen-b...  Yaa Mohaideen Briyani
# 1  https://www.zomato.com/chennai/sukkubhai-biriy...     Sukkubhai Biriyani
# 2  https://www.zomato.com/chennai/ss-hyderabad-bi...   SS Hyderabad Biryani
# 3        https://www.zomato.com/chennai/kfc-perambur                    KFC
# 4  https://www.zomato.com/chennai/tasty-kitchen-p...          Tasty Kitchen
#
#                                              Address     Location  \
# 0          336 & 338, Main Road, Pallavaram, Chennai   Pallavaram
# 1   New 14, Old 11/3Q, Railway Station Road, MKN ...      Alandur
# 2   98/339, Arcot Road, Opposite Gokulam Chit Fun...  Kodambakkam
# 3   10, Periyar Nagar, 70 Feet Road, Near Sheeba ...     Perambur
# 4   135B, SRP Colony, Peravallur, Near Perambur, ...     Perambur
#
#                                              Cuisine  \
# 0                                        ['Biryani']
# ...

# %% [markdown]
# # Get some basic information about the dataSet

# %%
# shape
dataSet.shape
# Out:
# (12032, 12)

# %%
# info -> dataset types
dataSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12032 entries, 0 to 12031
# Data columns (total 12 columns):
# Zomato URL               12032 non-null object
# Name of Restaurant       12032 non-null object
# Address                  12032 non-null object
# Location                 12032 non-null object
# Cuisine                  12032 non-null object
# Top Dishes               12032 non-null object
# Price for 2              12032 non-null float64
# Dining Rating            12032 non-null object
# Dining Rating Count      12032 non-null object
# Delivery Rating          12032 non-null object
# Delivery Rating Count    12032 non-null object
# Features                 12032 non-null object
# dtypes: float64(1), object(11)
# memory usage: 1.1+ MB

# %%
dataSet['Price for 2'] = dataSet['Price for 2'].astype('str')

# %%
dataSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12032 entries, 0 to 12031
# Data columns (total 12 columns):
# Zomato URL               12032 non-null object
# Name of Restaurant       12032 non-null object
# Address                  12032 non-null object
# Location                 12032 non-null object
# Cuisine                  12032 non-null object
# Top Dishes               12032 non-null object
# Price for 2              12032 non-null object
# Dining Rating            12032 non-null object
# Dining Rating Count      12032 non-null object
# Delivery Rating          12032 non-null object
# Delivery Rating Count    12032 non-null object
# Features                 12032 non-null object
# dtypes: object(12)
# memory usage: 1.1+ MB

# %%
dataSet.describe()
# Out:
#                                                Zomato URL Name of Restaurant  \
# count                                               12032              12032
# unique                                              12032               8369
# top     https://www.zomato.com/chennai/desi-chulla-kil...      Amma Unavagam
# freq                                                    1                 78
#
#                Address Location           Cuisine Top Dishes Price for 2  \
# count            12032    12032             12032      12032       12032
# unique           10828      268              2423       2190          64
# top      Delivery Only    Porur  ['South Indian']    Invalid       300.0
# freq               443      418               883       9641        2014
#
#        Dining Rating    Dining Rating Count Delivery Rating  \
# count          12032                  12032           12032
# unique            35                    794              33
# ...

# %% [markdown]
# # Remove unwanted columns

# %%
dataSet.columns
# Out:
# Index(['Zomato URL', 'Name of Restaurant', 'Address', 'Location', 'Cuisine',
#        'Top Dishes', 'Price for 2', 'Dining Rating', 'Dining Rating Count',
#        'Delivery Rating', 'Delivery Rating Count', 'Features'],
#       dtype='object')

# %%
dataSet.head(3)
# Out:
#                                           Zomato URL     Name of Restaurant  \
# 0  https://www.zomato.com/chennai/yaa-mohaideen-b...  Yaa Mohaideen Briyani
# 1  https://www.zomato.com/chennai/sukkubhai-biriy...     Sukkubhai Biriyani
# 2  https://www.zomato.com/chennai/ss-hyderabad-bi...   SS Hyderabad Biryani
#
#                                              Address     Location  \
# 0          336 & 338, Main Road, Pallavaram, Chennai   Pallavaram
# 1   New 14, Old 11/3Q, Railway Station Road, MKN ...      Alandur
# 2   98/339, Arcot Road, Opposite Gokulam Chit Fun...  Kodambakkam
#
#                                              Cuisine  \
# 0                                        ['Biryani']
# 1  ['Biryani', ' North Indian', ' Mughlai', ' Des...
# 2  ['Biryani', ' North Indian', ' Chinese', ' Ara...
#
#                                           Top Dishes Price for 2  \
# 0  ['Bread Halwa', ' Chicken 65', ' Mutton Biryan...       500.0
# ...

# %%
# remove the url and address
dataSet = dataSet.drop(['Zomato URL', 'Address', 'Features'], axis = 1)

# %%
dataSet.head()
# Out:
#       Name of Restaurant     Location  \
# 0  Yaa Mohaideen Briyani   Pallavaram
# 1     Sukkubhai Biriyani      Alandur
# 2   SS Hyderabad Biryani  Kodambakkam
# 3                    KFC     Perambur
# 4          Tasty Kitchen     Perambur
#
#                                              Cuisine  \
# 0                                        ['Biryani']
# 1  ['Biryani', ' North Indian', ' Mughlai', ' Des...
# 2  ['Biryani', ' North Indian', ' Chinese', ' Ara...
# 3  ['Burger', ' Fast Food', ' Finger Food', ' Bev...
# 4  ['Chinese', ' Biryani', ' North Indian', ' Che...
#
#                                           Top Dishes Price for 2  \
# 0  ['Bread Halwa', ' Chicken 65', ' Mutton Biryan...       500.0
# 1  ['Beef Biryani', ' Beef Fry', ' Paratha', ' Pa...      1000.0
# 2  ['Brinjal Curry', ' Tandoori Chicken', ' Chick...       500.0
# 3                                  ['Zinger Burger']       500.0
# 4  ['Mutton Biryani', ' Chicken Rice', ' Tomato R...       450.0
#
# ...

# %% [markdown]
# # Describe the dataset

# %%
dataSet.describe()
# Out:
#        Name of Restaurant Location           Cuisine Top Dishes Price for 2  \
# count               12032    12032             12032      12032       12032
# unique               8369      268              2423       2190          64
# top         Amma Unavagam    Porur  ['South Indian']    Invalid       300.0
# freq                   78      418               883       9641        2014
#
#        Dining Rating    Dining Rating Count Delivery Rating  \
# count          12032                  12032           12032
# unique            35                    794              33
# top             None  Does not offer Dining            None
# freq            5351                   2603            5851
#
#               Delivery Rating Count
# count                         12032
# unique                         2282
# top     Not enough Delivery Reviews
# freq                           3379

# %% [markdown]
# # check the null data

# %%
dataSet.isnull().sum()
# Out:
# Name of Restaurant       0
# Location                 0
# Cuisine                  0
# Top Dishes               0
# Price for 2              0
# Dining Rating            0
# Dining Rating Count      0
# Delivery Rating          0
# Delivery Rating Count    0
# dtype: int64

# %% [markdown]
# # work in Cuisine

# %%
dataSet['Cuisine'] =  dataSet['Cuisine'].str.replace('[', '', regex = True)
dataSet['Cuisine'] =  dataSet['Cuisine'].str.replace(']', '', regex = True)

# %%
dataSet.head()
# Out:
#       Name of Restaurant     Location  \
# 0  Yaa Mohaideen Briyani   Pallavaram
# 1     Sukkubhai Biriyani      Alandur
# 2   SS Hyderabad Biryani  Kodambakkam
# 3                    KFC     Perambur
# 4          Tasty Kitchen     Perambur
#
#                                              Cuisine  \
# 0                                          'Biryani'
# 1  'Biryani', ' North Indian', ' Mughlai', ' Dess...
# 2  'Biryani', ' North Indian', ' Chinese', ' Arab...
# 3  'Burger', ' Fast Food', ' Finger Food', ' Beve...
# 4  'Chinese', ' Biryani', ' North Indian', ' Chet...
#
#                                           Top Dishes Price for 2  \
# 0  ['Bread Halwa', ' Chicken 65', ' Mutton Biryan...       500.0
# 1  ['Beef Biryani', ' Beef Fry', ' Paratha', ' Pa...      1000.0
# 2  ['Brinjal Curry', ' Tandoori Chicken', ' Chick...       500.0
# 3                                  ['Zinger Burger']       500.0
# 4  ['Mutton Biryani', ' Chicken Rice', ' Tomato R...       450.0
#
# ...

# %% [markdown]
# # work in Cuisine

# %%
dataSet['Top Dishes'] =  dataSet['Top Dishes'].str.replace('[', '', regex = True)
dataSet['Top Dishes'] =  dataSet['Top Dishes'].str.replace(']', '', regex = True)

# %%
dataSet.head()
# Out:
#       Name of Restaurant     Location  \
# 0  Yaa Mohaideen Briyani   Pallavaram
# 1     Sukkubhai Biriyani      Alandur
# 2   SS Hyderabad Biryani  Kodambakkam
# 3                    KFC     Perambur
# 4          Tasty Kitchen     Perambur
#
#                                              Cuisine  \
# 0                                          'Biryani'
# 1  'Biryani', ' North Indian', ' Mughlai', ' Dess...
# 2  'Biryani', ' North Indian', ' Chinese', ' Arab...
# 3  'Burger', ' Fast Food', ' Finger Food', ' Beve...
# 4  'Chinese', ' Biryani', ' North Indian', ' Chet...
#
#                                           Top Dishes Price for 2  \
# 0  'Bread Halwa', ' Chicken 65', ' Mutton Biryani...       500.0
# 1  'Beef Biryani', ' Beef Fry', ' Paratha', ' Pay...      1000.0
# 2  'Brinjal Curry', ' Tandoori Chicken', ' Chicke...       500.0
# 3                                    'Zinger Burger'       500.0
# 4  'Mutton Biryani', ' Chicken Rice', ' Tomato Ri...       450.0
#
# ...

# %%
dataSet.describe()
# Out:
#        Name of Restaurant Location         Cuisine Top Dishes Price for 2  \
# count               12032    12032           12032      12032       12032
# unique               8369      268            2423       2190          64
# top         Amma Unavagam    Porur  'South Indian'    Invalid       300.0
# freq                   78      418             883       9641        2014
#
#        Dining Rating    Dining Rating Count Delivery Rating  \
# count          12032                  12032           12032
# unique            35                    794              33
# top             None  Does not offer Dining            None
# freq            5351                   2603            5851
#
#               Delivery Rating Count
# count                         12032
# unique                         2282
# top     Not enough Delivery Reviews
# freq                           3379

# %%
dataSet[dataSet['Top Dishes'] == 'Invalid']
# Out:
#        Name of Restaurant         Location  \
# 72          Deen Biriyani     Aminijikarai
# 240    Smoke Hub Barbeque        Velachery
# 291      Nellai Fast Food  Thousand Lights
# 294         Hunger Palato       Medavakkam
# 436     Kebab@Lake Street        Velachery
# ...                   ...              ...
# 12027     CK's Sandwiches            Porur
# 12028     CK's Sandwiches         Kolathur
# 12029     CK's Sandwiches  Anna Nagar East
# 12030     CK's Sandwiches        Ramapuram
# 12031     CK's Sandwiches   Sholinganallur
#
#                                                  Cuisine Top Dishes  \
# 72     'Biryani', ' South Indian', ' North Indian', '...    Invalid
# 240    'BBQ', ' Asian', ' North Indian', ' Desserts',...    Invalid
# 291               'Chinese', ' Biryani', ' North Indian'    Invalid
# 294                         'Momos', ' Steak', ' Burger'    Invalid
# 436          'Kebab', ' Mughlai', ' Chinese', ' Biryani'    Invalid
# ...

# %% [markdown]
# # work in price

# %%
# Out:
# pandas.core.series.Series
